# %% [markdown]
# # Melanoma, Fundoscopy - InceptionV3
# -----------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time
import torch
import torchvision
from torchvision import transforms, models
from torch import nn, optim
import torch.nn.functional as F
import sklearn.metrics as metrics

print("Do you want to run the training process? (y / n)")
i = input()
if i == 'y':
    train_model = True
else:
    train_model = False
    
fpath = "/home/arttu/Documents/research/melanoma/"
# fpath = "hakkina7@triton.aalto.fi:/scratch/work/hakkina7/research/melanoma/"
print("File path is {}".format(fpath))

# Set the device
dev = "cuda:0" if torch.cuda.is_available() else "cpu"
device = torch.device(dev)
print("Device is {}".format(device))

# Set file name
fname = 'inceptionV3.pth'
# Out:
# Do you want to run the training process? (y / n)
# y
# File path is /home/arttu/Documents/research/melanoma/
# Device is cpu

# %% [markdown]
# ## Data preprocessing
# --------------

# %% [markdown]
# ### Important: In contrast to the other models the inception_v3 expects tensors with a size of N x 3 x 299 x 299, so ensure your images are sized accordingly.

# %%
# Takes a while to run the mean and std calculation, so save the values here
# NB: These have to be calculated again if the image size is changed
# NB: Modifying the batch size doesn't matter, mean and std stay the same
# mean = [0.485, 0.456, 0.406] # https://pytorch.org/hub/pytorch_vision_inception_v3/
# std = [0.229, 0.224, 0.225] # https://pytorch.org/hub/pytorch_vision_inception_v3/

h, w = (299, 299)
# Get proper dataloader with normalized images
transformations = transforms.Compose([
    transforms.Resize((h, w)),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor([0.0, 0.0, 0.0]), torch.Tensor([1.0, 1.0, 1.0]))
])

trainset = torchvision.datasets.ImageFolder(root=fpath+"data/train/",
                                           transform=transformations)
testset = torchvision.datasets.ImageFolder(root=fpath+"data/test/",
                                           transform=transformations)
valset = torchvision.datasets.ImageFolder(root=fpath+"data/val/",
                                           transform=transformations)

trainloader = torch.utils.data.DataLoader(dataset=trainset, batch_size=32, shuffle=True)
testloader = torch.utils.data.DataLoader(dataset=testset, batch_size=8, shuffle=False)
valloader = torch.utils.data.DataLoader(dataset=valset, batch_size=5, shuffle=False)

print("Show some images? (y / n)")
i = input()
if i == 'y':
    show = True
else:
    show = False

if show:
    # Show some images after transformations
    loader = torch.utils.data.DataLoader(dataset=trainset, batch_size=9, shuffle=True)
    images, labels = next(iter(loader))
    grid=torchvision.utils.make_grid(images, nrow=3)
    plt.figure(figsize=(10,40))
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    print(labels)
# Out:
# Show some images? (y / n)
# y
# tensor([5, 1, 1, 5, 5, 5, 5, 5, 1])

# %% [markdown]
# ## Training
# --------------

# %%
def train(model, epochs, trainloader, testloader, device, optimizer, loss_fn, weights):
    """Training loop"""
    
    for epoch in range(epochs):
        model.train()
        best_acc = 0
        losses = []
        correct = 0
        total = 0
        start = time.time()
        for i, (images, labels) in enumerate(trainloader):
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs, _ = model(images)
            _, pred = torch.max(outputs, 1)
            correct += (labels == pred).sum().item()
            total += labels.size(0)
            loss = loss_fn(outputs, labels)
            losses.append(loss.item())
            loss.backward()
            optimizer.step()
            print("Batch {}/{}: {:.2f} seconds".format(i+1, len(trainloader), time.time()-start))
            start=time.time()
        acc = 100 * correct/total
        print("\nEpoch {}:\nMean loss {} - Correctly labeled training images {:.2f}%".format(epoch+1,
                                                                                           np.mean(losses),
                                                                                           acc))
        
        model.eval()
        correct = 0
        total = 0
        true = torch.zeros(0, dtype=torch.long, device='cpu')
        preds = torch.zeros(0, dtype=torch.long, device='cpu')
        probs = torch.zeros(0, dtype=torch.float, device='cpu')
        with torch.no_grad():
            start = time.time()
            for i, (images, labels) in enumerate(testloader):
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, pred = torch.max(outputs, 1)
                correct += (pred == labels).sum().item()
                total += labels.size(0)
                true = torch.cat([true, labels.view(-1)])
                preds = torch.cat([preds, pred.view(-1)])
                prob, _ = (F.softmax(outputs, dim=1)).topk(1, dim=1)
                probs = torch.cat([probs, prob.view(-1)])
                print("Batch {}/{}: {:.2f} seconds".format(i+1, len(testloader), time.time()-start))
                start=time.time()
                
        acc = 100 * correct/total
        print("Classified {:.2f} % of test images correctly.".format(
            acc
        ))
        print("Precision on test set: {}".format(
            metrics.precision_score(true.numpy(),
                                    preds.numpy(),
                                    average=None)
        ))
        print("Recall on test set: {}".format(
            metrics.recall_score(true.numpy(),
                                 preds.numpy(), 
                                 average=None)
        ))
        print("F1-score on test set: {}".format(
            metrics.f1_score(true.numpy(),
                             preds.numpy(),
                             average=None)
        ))
        classes = ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'VASC']
        aucs = {}
        for i, c in enumerate(classes):
            fpr, tpr, _ = metrics.roc_curve(true.numpy(),
                                            probs.numpy(), 
                                            pos_label=i)
            aucs[c] = metrics.auc(fpr, tpr)
        print("ROC AUC on test set: {}".format(aucs))
        print("Confusion matrix on test set:")
        print(pd.DataFrame(metrics.confusion_matrix(true.numpy(), preds.numpy()), 
                           columns=['pred as AK', 'pred as BCC', 
                                    'pred as BKL', 'pred as DF',
                                    'pred as MEL', 'pred as NV',
                                    'pred as SCC', 'pred as VASC'], 
                           index=['true class AK', 'true class BCC',
                                  'true class BKL', 'true class DF',
                                  'true class MEL', 'true class NV',
                                  'true class SCC', 'true class VASC']))
        print()

    print("Training finished.")

    return model


if train_model:
    print("Training InceptionV3 model for Fundoscopy classification task.")
    
    # Initialize the model
    model = models.inception_v3(pretrained=False)
    n_labels = 8
    n_inputs = model.fc.in_features
    model.fc = nn.Linear(n_inputs, n_labels)
    model = model.to(device)
    
    # Calculate weights for the weighted loss function. We need the weighted loss,
    # because of the class imbalance that is present on the data sets. If
    # weighted loss fails, try focal loss with alpha=0.25 and gamma=2.
    n_samples = [694, 2658, 2099, 191, 3618, 10300, 502, 202]
    weights = [1 / (x / sum(n_samples)) for x in n_samples]  # More weight on the samples that appear less
    weights = torch.FloatTensor(weights).to(device)
    print("Since there is class imbalance present in some of the data sets, use the following weights in the loss function:")
    print(weights)
    print()
    
    # Train model
    model = train(model=model,
                  epochs=100,
                  trainloader=trainloader,
                  testloader=testloader,
                  device=device,
                  optimizer=optim.SGD(list(model.parameters()),
                                      lr=1e-3,
                                      momentum=0.9),
                  loss_fn=nn.CrossEntropyLoss(weight=weights),
                  weights=weights)
    
    # Save the trained model
    torch.save(model.state_dict(), fpath+fname)
    print("Model succesfully saved to {}".format(fpath+fname))
# Out:
# Training InceptionV3 model for Fundoscopy classification task.
# /home/arttu/miniconda3/envs/leanheat/lib/python3.6/site-packages/torchvision/models/inception.py:82: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   ' due to scipy/scipy#11299), please set init_weights=True.', FutureWarning)
# Since there is class imbalance present in some of the data sets, use the following weights in the loss function:
# tensor([ 29.1988,   7.6238,   9.6541, 106.0942,   5.6009,   1.9674,  40.3665,
#         100.3168])
#
# Batch 1/254: 0.76 seconds
# Batch 2/254: 0.67 seconds
# Batch 3/254: 0.62 seconds
# Batch 4/254: 0.63 seconds
# Batch 5/254: 0.64 seconds
# Batch 6/254: 0.63 seconds
# Batch 7/254: 0.65 seconds
# Batch 8/254: 0.65 seconds
# Batch 9/254: 0.65 seconds
# Batch 10/254: 0.58 seconds
# Batch 11/254: 0.58 seconds
# Batch 12/254: 0.58 seconds
# Batch 13/254: 0.58 seconds
# Batch 14/254: 0.63 seconds
# Batch 15/254: 0.66 seconds
# Batch 16/254: 0.65 seconds
# Batch 17/254: 0.96 seconds
# Batch 18/254: 0.72 seconds
# Batch 19/254: 0.67 seconds
# Batch 20/254: 0.66 seconds
# Batch 21/254: 0.66 seconds
# Batch 22/254: 0.66 seconds
# Batch 23/254: 0.67 seconds
# Batch 24/254: 0.72 seconds
# Batch 25/254: 0.71 seconds
# Batch 26/254: 0.68 seconds
# Batch 27/254: 0.67 seconds
# Batch 28/254: 0.67 seconds
# Batch 29/254: 0.68 seconds
# Batch 30/254: 0.67 seconds
# Batch 31/254: 0.73 seconds
# Batch 32/254: 0.96 seconds
# Batch 33/254: 0.71 seconds
# Batch 34/254: 0.68 seconds
# Batch 35/254: 0.71 seconds
# Batch 36/254: 0.75 seconds
# Batch 37/254: 0.71 seconds
# Batch 38/254: 0.70 seconds
# Batch 39/254: 0.75 seconds
# Batch 40/254: 0.71 seconds
# Batch 41/254: 0.70 seconds
# Batch 42/254: 0.68 seconds
# Batch 43/254: 0.63 seconds
# Batch 44/254: 0.65 seconds
# Batch 45/254: 0.66 seconds
# Batch 46/254: 0.67 seconds
# Batch 47/254: 0.86 seconds
# Batch 48/254: 0.65 seconds
# Batch 49/254: 0.67 seconds
# Batch 50/254: 0.66 seconds
# Batch 51/254: 0.65 seconds
# Batch 52/254: 0.63 seconds
# Batch 53/254: 0.64 seconds
# Batch 54/254: 0.62 seconds
# Batch 55/254: 0.66 seconds
# Batch 56/254: 0.64 seconds
# Batch 57/254: 0.69 seconds
# Batch 58/254: 0.70 seconds
# Batch 59/254: 0.76 seconds
# Batch 60/254: 0.75 seconds
# Batch 61/254: 0.78 seconds
# Batch 62/254: 0.90 seconds
# Batch 63/254: 0.72 seconds
# Batch 64/254: 0.71 seconds
# Batch 65/254: 0.79 seconds
# Batch 66/254: 0.73 seconds
# Batch 67/254: 0.79 seconds
# Batch 68/254: 0.73 seconds
# Batch 69/254: 0.76 seconds
# Batch 70/254: 0.72 seconds
# Batch 71/254: 0.67 seconds
# Batch 72/254: 0.63 seconds
# Batch 73/254: 0.64 seconds
# Batch 74/254: 0.65 seconds
# Batch 75/254: 0.64 seconds
# Batch 76/254: 0.70 seconds
# Batch 77/254: 0.92 seconds
# Batch 78/254: 0.64 seconds
# Batch 79/254: 0.62 seconds
# Batch 80/254: 0.62 seconds
# Batch 81/254: 0.62 seconds
# Batch 82/254: 0.62 seconds
# Batch 83/254: 0.63 seconds
# Batch 84/254: 0.67 seconds
# Batch 85/254: 0.63 seconds
# Batch 86/254: 0.69 seconds
# Batch 87/254: 0.67 seconds
# Batch 88/254: 0.71 seconds
# Batch 89/254: 0.72 seconds
# Batch 90/254: 0.75 seconds
# Batch 91/254: 0.75 seconds
# Batch 92/254: 1.08 seconds
# Batch 93/254: 0.69 seconds
# Batch 94/254: 0.69 seconds
# Batch 95/254: 0.69 seconds
# Batch 96/254: 0.72 seconds
# Batch 97/254: 0.70 seconds
# Batch 98/254: 0.69 seconds
# Batch 99/254: 0.79 seconds
# Batch 100/254: 0.69 seconds
# Batch 101/254: 0.68 seconds
# Batch 102/254: 0.68 seconds
# Batch 103/254: 0.69 seconds
# Batch 104/254: 0.70 seconds
# Batch 105/254: 0.68 seconds
# Batch 106/254: 0.90 seconds
# Batch 107/254: 0.72 seconds
# Batch 108/254: 0.68 seconds
# Batch 109/254: 0.68 seconds
# Batch 110/254: 0.68 seconds
# Batch 111/254: 0.70 seconds
# Batch 112/254: 0.68 seconds
# Batch 113/254: 0.68 seconds
# Batch 114/254: 0.73 seconds
# Batch 115/254: 0.69 seconds
# Batch 116/254: 0.71 seconds
# Batch 117/254: 0.63 seconds
# Batch 118/254: 0.64 seconds
# Batch 119/254: 0.63 seconds
# Batch 120/254: 0.64 seconds
# Batch 121/254: 0.80 seconds
# Batch 122/254: 0.84 seconds
# Batch 123/254: 0.64 seconds
# Batch 124/254: 0.64 seconds
# Batch 125/254: 0.64 seconds
# Batch 126/254: 0.63 seconds
# Batch 127/254: 0.65 seconds
# Batch 128/254: 0.65 seconds
# Batch 129/254: 0.70 seconds
# Batch 130/254: 0.64 seconds
# Batch 131/254: 0.64 seconds
# Batch 132/254: 0.64 seconds
# Batch 133/254: 0.64 seconds
# Batch 134/254: 0.64 seconds
# Batch 135/254: 0.66 seconds
# Batch 136/254: 0.65 seconds
# Batch 137/254: 0.94 seconds
# Batch 138/254: 0.66 seconds
# Batch 139/254: 0.65 seconds
# Batch 140/254: 0.64 seconds
# Batch 141/254: 0.65 seconds
# Batch 142/254: 0.63 seconds
# Batch 143/254: 0.62 seconds
# Batch 144/254: 0.62 seconds
# Batch 145/254: 0.68 seconds
# Batch 146/254: 0.62 seconds
# Batch 147/254: 0.62 seconds
# Batch 148/254: 0.62 seconds
# Batch 149/254: 0.62 seconds
# Batch 150/254: 0.62 seconds
# Batch 151/254: 0.62 seconds
# Batch 152/254: 0.61 seconds
# Batch 153/254: 0.81 seconds
# Batch 154/254: 0.71 seconds
# Batch 155/254: 0.63 seconds
# Batch 156/254: 0.62 seconds
# Batch 157/254: 0.62 seconds
# Batch 158/254: 0.62 seconds
# Batch 159/254: 0.67 seconds
# Batch 160/254: 0.63 seconds
# Batch 161/254: 0.69 seconds
# Batch 162/254: 0.62 seconds
# Batch 163/254: 0.62 seconds
# Batch 164/254: 0.62 seconds
# Batch 165/254: 0.62 seconds
# Batch 166/254: 0.62 seconds
# Batch 167/254: 0.63 seconds
# Batch 168/254: 0.62 seconds
# Batch 169/254: 0.73 seconds
# Batch 170/254: 0.75 seconds
# Batch 171/254: 0.67 seconds
# Batch 172/254: 0.83 seconds
# Batch 173/254: 0.66 seconds
# Batch 174/254: 0.67 seconds
# Batch 175/254: 0.93 seconds
# Batch 176/254: 0.64 seconds
# Batch 177/254: 0.72 seconds
# Batch 178/254: 0.62 seconds
# Batch 179/254: 0.63 seconds
# Batch 180/254: 0.63 seconds
# Batch 181/254: 0.63 seconds
# Batch 182/254: 0.63 seconds
# Batch 183/254: 0.62 seconds
# Batch 184/254: 0.63 seconds
# Batch 185/254: 0.91 seconds
# Batch 186/254: 0.63 seconds
# Batch 187/254: 0.62 seconds
# Batch 188/254: 0.62 seconds
# Batch 189/254: 0.62 seconds
# Batch 190/254: 0.66 seconds
# Batch 191/254: 0.62 seconds
# Batch 192/254: 0.62 seconds
# Batch 193/254: 0.68 seconds
# Batch 194/254: 0.63 seconds
# Batch 195/254: 0.63 seconds
# Batch 196/254: 0.62 seconds
# Batch 197/254: 0.63 seconds
# Batch 198/254: 0.69 seconds
# Batch 199/254: 0.63 seconds
# Batch 200/254: 0.62 seconds
# Batch 201/254: 0.93 seconds
# Batch 202/254: 0.66 seconds
# Batch 203/254: 0.62 seconds
# Batch 204/254: 0.63 seconds
# Batch 205/254: 0.67 seconds
# Batch 206/254: 0.69 seconds
# Batch 207/254: 0.73 seconds
# Batch 208/254: 0.83 seconds
# Batch 209/254: 0.71 seconds
# Batch 210/254: 0.72 seconds
# Batch 211/254: 0.73 seconds
# Batch 212/254: 0.72 seconds
# Batch 213/254: 0.75 seconds
# Batch 214/254: 0.73 seconds
# Batch 215/254: 0.95 seconds
# Batch 216/254: 0.81 seconds
# Batch 217/254: 0.70 seconds
# Batch 218/254: 0.72 seconds
# Batch 219/254: 0.74 seconds
# Batch 220/254: 0.69 seconds
# Batch 221/254: 0.70 seconds
# Batch 222/254: 0.76 seconds
# Batch 223/254: 0.69 seconds
# Batch 224/254: 0.69 seconds
# Batch 225/254: 0.69 seconds
# Batch 226/254: 0.70 seconds
# Batch 227/254: 0.69 seconds
# Batch 228/254: 0.70 seconds
# Batch 229/254: 0.69 seconds
# Batch 230/254: 0.91 seconds
# Batch 231/254: 0.70 seconds
# Batch 232/254: 0.69 seconds
# Batch 233/254: 0.69 seconds
# Batch 234/254: 0.68 seconds
# Batch 235/254: 0.75 seconds
# Batch 236/254: 0.69 seconds
# Batch 237/254: 0.75 seconds
# Batch 238/254: 0.70 seconds
# Batch 239/254: 0.69 seconds
# Batch 240/254: 0.70 seconds
# Batch 241/254: 0.69 seconds
# Batch 242/254: 0.70 seconds
# Batch 243/254: 0.69 seconds
# Batch 244/254: 0.82 seconds
# Batch 245/254: 0.85 seconds
# Batch 246/254: 0.62 seconds
# Batch 247/254: 0.62 seconds
# Batch 248/254: 0.69 seconds
# Batch 249/254: 0.69 seconds
# Batch 250/254: 0.70 seconds
# Batch 251/254: 0.69 seconds
# Batch 252/254: 0.68 seconds
# Batch 253/254: 0.67 seconds
# Batch 254/254: 0.43 seconds
# (1268,) (1268,)
# Classified 17.82 % of test images correctly.
# Precision on test set: [0.         0.         0.         0.         0.17823344 0.
#  0.         0.        ]
# Recall on test set: [0. 0. 0. 0. 1. 0. 0. 0.]
# F1-score on test set: [0.         0.         0.         0.         0.30254351 0.
#  0.         0.        ]
# ROC AUC on test set: {'AK': 0.5, 'BCC': 0.5, 'BKL': 0.5, 'DF': 0.5, 'MEL': 0.5, 'NV': 0.5, 'SCC': 0.5, 'VASC': 0.5}
# Confusion matrix on test set:
#                  pred as AK  pred as BCC  pred as BKL  pred as DF  \
# true class AK             0            0            0           0
# true class BCC            0            0            0           0
# true class BKL            0            0            0           0
# true class DF             0            0            0           0
# true class MEL            0            0            0           0
# true class NV             0            0            0           0
# true class SCC            0            0            0           0
# true class VASC           0            0            0           0
#
#                  pred as MEL  pred as NV  pred as SCC  pred as VASC
# true class AK             43           0            0             0
# true class BCC           167           0            0             0
# true class BKL           131           0            0             0
# true class DF             12           0            0             0
# true class MEL           226           0            0             0
# true class NV            644           0            0             0
# true class SCC            32           0            0             0
# true class VASC           13           0            0             0
#
# Training finished.
# Model succesfully saved to /home/arttu/Documents/research/melanoma/inceptionV3.pth
# /home/arttu/miniconda3/envs/leanheat/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Evaluate
# ---------------

# %%
def evaluate(model, valloader, device):
    """Evaluate model performance on validation set"""
    
    model.eval()
    correct = 0
    total = 0
    true = torch.zeros(0, dtype=torch.long, device='cpu')
    preds = torch.zeros(0, dtype=torch.long, device='cpu')
    probs = torch.zeros(0, dtype=torch.float, device='cpu')
    with torch.no_grad():
        start = time.time()
        for i, (images, labels) in enumerate(valloader):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, pred = torch.max(outputs, 1)
            correct += (pred == labels).sum().item()
            total += labels.size(0)
            true = torch.cat([true, labels.view(-1)])
            preds = torch.cat([preds, pred.view(-1)])
            prob, _ = (F.softmax(outputs, dim=1)).topk(1, dim=1)
            probs = torch.cat([probs, prob.view(-1)])
            print("Batch {}/{}: {:.2f} seconds".format(i+1, len(valloader), time.time()-start))
            start=time.time()
    
    acc = 100 * correct/total
    print("Classified {:.2f} % of validation images correctly.".format(
        acc
    ))
    print("Precision on validation set: {}".format(
        metrics.precision_score(true.numpy(),
                                preds.numpy(),
                                average=None)
    ))
    print("Recall on validation set: {}".format(
        metrics.recall_score(true.numpy(),
                             preds.numpy(), 
                             average=None)
    ))
    print("F1-score on validation set: {}".format(
        metrics.f1_score(true.numpy(),
                         preds.numpy(),
                         average=None)
    ))
    classes = ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'VASC']
    aucs = {}
    for i, c in enumerate(classes):
        fpr, tpr, _ = metrics.roc_curve(true.numpy(),
                                        probs.numpy(), 
                                        pos_label=i)
        aucs[c] = metrics.auc(fpr, tpr)
        plt.plot(fpr, tpr, label='{} AUC = {:.2f}'.format(c, metrics.auc(fpr, tpr)))
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    print("ROC AUC on validation set: {}".format(aucs))
    print("Confusion matrix on validation set:")
    print(pd.DataFrame(metrics.confusion_matrix(true.numpy(), preds.numpy()), 
                       columns=['pred as AK', 'pred as BCC', 
                                'pred as BKL', 'pred as DF',
                                'pred as MEL', 'pred as NV',
                                'pred as SCC', 'pred as VASC'], 
                       index=['true class AK', 'true class BCC',
                              'true class BKL', 'true class DF',
                              'true class MEL', 'true class NV',
                              'true class SCC', 'true class VASC']))
    print()
    

# Initialize model
model = models.inception_v3(pretrained=False)
n_labels = 8
n_inputs = model.fc.in_features
model.fc = nn.Linear(n_inputs, n_labels)

# Load model params
if torch.cuda.is_available():
    model.load_state_dict(torch.load(fpath+fname))
    model.to(device)
else:
    model.load_state_dict(torch.load(fpath+fname,
                                     map_location=torch.device('cpu')))
    
print("Model succesfully loaded from {}".format(fpath+fname))

# Evaluate the model performance on validation set
print("Evaluating the InceptionV3 model on the validation set.")
evaluate(model, valloader, device)
# Out:
# Model succesfully loaded from /home/arttu/Documents/research/melanoma/inceptionV3.pth
# Evaluating the InceptionV3 model on the validation set.
# Batch 1/254: 0.57 seconds
# Batch 2/254: 0.63 seconds
# Batch 3/254: 0.65 seconds
# Batch 4/254: 0.68 seconds
# Batch 5/254: 0.69 seconds
# Batch 6/254: 0.73 seconds
# Batch 7/254: 0.66 seconds
# Batch 8/254: 0.72 seconds
# Batch 9/254: 0.66 seconds
# Batch 10/254: 0.61 seconds
# Batch 11/254: 0.59 seconds
# Batch 12/254: 0.61 seconds
# Batch 13/254: 0.59 seconds
# Batch 14/254: 0.83 seconds
# Batch 15/254: 0.66 seconds
# Batch 16/254: 0.66 seconds
# Batch 17/254: 0.67 seconds
# Batch 18/254: 0.70 seconds
# Batch 19/254: 0.67 seconds
# Batch 20/254: 0.68 seconds
# Batch 21/254: 0.74 seconds
# Batch 22/254: 0.69 seconds
# Batch 23/254: 0.67 seconds
# Batch 24/254: 0.70 seconds
# Batch 25/254: 0.69 seconds
# Batch 26/254: 0.71 seconds
# Batch 27/254: 0.69 seconds
# Batch 28/254: 0.69 seconds
# Batch 29/254: 0.99 seconds
# Batch 30/254: 0.70 seconds
# Batch 31/254: 0.68 seconds
# Batch 32/254: 0.71 seconds
# Batch 33/254: 0.69 seconds
# Batch 34/254: 0.70 seconds
# Batch 35/254: 0.67 seconds
# Batch 36/254: 0.75 seconds
# Batch 37/254: 0.68 seconds
# Batch 38/254: 0.69 seconds
# Batch 39/254: 0.68 seconds
# Batch 40/254: 0.68 seconds
# Batch 41/254: 0.68 seconds
# Batch 42/254: 0.68 seconds
# Batch 43/254: 0.64 seconds
# Batch 44/254: 0.83 seconds
# Batch 45/254: 0.64 seconds
# Batch 46/254: 0.64 seconds
# Batch 47/254: 0.62 seconds
# Batch 48/254: 0.61 seconds
# Batch 49/254: 0.65 seconds
# Batch 50/254: 0.62 seconds
# Batch 51/254: 0.62 seconds
# Batch 52/254: 0.72 seconds
# Batch 53/254: 0.61 seconds
# Batch 54/254: 0.61 seconds
# Batch 55/254: 0.61 seconds
# Batch 56/254: 0.63 seconds
# Batch 57/254: 0.67 seconds
# Batch 58/254: 0.68 seconds
# Batch 59/254: 0.68 seconds
# Batch 60/254: 0.92 seconds
# Batch 61/254: 0.75 seconds
# Batch 62/254: 0.74 seconds
# Batch 63/254: 0.70 seconds
# Batch 64/254: 0.79 seconds
# Batch 65/254: 0.71 seconds
# Batch 66/254: 0.72 seconds
# Batch 67/254: 0.79 seconds
# Batch 68/254: 0.69 seconds
# Batch 69/254: 0.67 seconds
# Batch 70/254: 0.69 seconds
# Batch 71/254: 0.68 seconds
# Batch 72/254: 0.63 seconds
# Batch 73/254: 0.64 seconds
# Batch 74/254: 0.84 seconds
# Batch 75/254: 0.76 seconds
# Batch 76/254: 0.65 seconds
# Batch 77/254: 0.63 seconds
# Batch 78/254: 0.66 seconds
# Batch 79/254: 0.61 seconds
# Batch 80/254: 0.63 seconds
# Batch 81/254: 0.62 seconds
# Batch 82/254: 0.68 seconds
# Batch 83/254: 0.62 seconds
# Batch 84/254: 0.62 seconds
# Batch 85/254: 0.61 seconds
# Batch 86/254: 0.61 seconds
# Batch 87/254: 0.64 seconds
# Batch 88/254: 0.69 seconds
# Batch 89/254: 0.69 seconds
# Batch 90/254: 0.94 seconds
# Batch 91/254: 0.74 seconds
# Batch 92/254: 0.69 seconds
# Batch 93/254: 0.67 seconds
# Batch 94/254: 0.72 seconds
# Batch 95/254: 0.68 seconds
# Batch 96/254: 0.68 seconds
# Batch 97/254: 0.73 seconds
# Batch 98/254: 0.68 seconds
# Batch 99/254: 0.70 seconds
# Batch 100/254: 0.70 seconds
# Batch 101/254: 0.68 seconds
# Batch 102/254: 0.69 seconds
# Batch 103/254: 0.69 seconds
# Batch 104/254: 0.69 seconds
# Batch 105/254: 0.97 seconds
# Batch 106/254: 0.73 seconds
# Batch 107/254: 0.68 seconds
# Batch 108/254: 0.68 seconds
# Batch 109/254: 0.70 seconds
# Batch 110/254: 0.70 seconds
# Batch 111/254: 0.69 seconds
# Batch 112/254: 0.74 seconds
# Batch 113/254: 0.68 seconds
# Batch 114/254: 0.69 seconds
# Batch 115/254: 0.69 seconds
# Batch 116/254: 0.68 seconds
# Batch 117/254: 0.63 seconds
# Batch 118/254: 0.64 seconds
# Batch 119/254: 0.63 seconds
# Batch 120/254: 0.93 seconds
# Batch 121/254: 0.65 seconds
# Batch 122/254: 0.63 seconds
# Batch 123/254: 0.64 seconds
# Batch 124/254: 0.64 seconds
# Batch 125/254: 0.65 seconds
# Batch 126/254: 0.64 seconds
# Batch 127/254: 0.64 seconds
# Batch 128/254: 0.70 seconds
# Batch 129/254: 0.70 seconds
# Batch 130/254: 0.65 seconds
# Batch 131/254: 0.64 seconds
# Batch 132/254: 0.65 seconds
# Batch 133/254: 0.66 seconds
# Batch 134/254: 0.64 seconds
# Batch 135/254: 0.70 seconds
# Batch 136/254: 0.75 seconds
# Batch 137/254: 0.66 seconds
# Batch 138/254: 0.65 seconds
# Batch 139/254: 0.65 seconds
# Batch 140/254: 0.64 seconds
# Batch 141/254: 0.66 seconds
# Batch 142/254: 0.63 seconds
# Batch 143/254: 0.62 seconds
# Batch 144/254: 0.77 seconds
# Batch 145/254: 0.66 seconds
# Batch 146/254: 0.64 seconds
# Batch 147/254: 0.64 seconds
# Batch 148/254: 0.64 seconds
# Batch 149/254: 0.63 seconds
# Batch 150/254: 0.62 seconds
# Batch 151/254: 0.74 seconds
# Batch 152/254: 0.77 seconds
# Batch 153/254: 0.64 seconds
# Batch 154/254: 0.62 seconds
# Batch 155/254: 0.62 seconds
# Batch 156/254: 0.62 seconds
# Batch 157/254: 0.75 seconds
# Batch 158/254: 0.85 seconds
# Batch 159/254: 0.69 seconds
# Batch 160/254: 0.65 seconds
# Batch 161/254: 0.62 seconds
# Batch 162/254: 0.63 seconds
# Batch 163/254: 0.62 seconds
# Batch 164/254: 0.63 seconds
# Batch 165/254: 0.62 seconds
# Batch 166/254: 0.62 seconds
# Batch 167/254: 0.85 seconds
# Batch 168/254: 0.76 seconds
# Batch 169/254: 0.62 seconds
# Batch 170/254: 0.62 seconds
# Batch 171/254: 0.63 seconds
# Batch 172/254: 0.62 seconds
# Batch 173/254: 0.63 seconds
# Batch 174/254: 0.63 seconds
# Batch 175/254: 0.68 seconds
# Batch 176/254: 0.64 seconds
# Batch 177/254: 0.62 seconds
# Batch 178/254: 0.62 seconds
# Batch 179/254: 0.62 seconds
# Batch 180/254: 0.62 seconds
# Batch 181/254: 0.63 seconds
# Batch 182/254: 0.62 seconds
# Batch 183/254: 0.80 seconds
# Batch 184/254: 0.72 seconds
# Batch 185/254: 0.62 seconds
# Batch 186/254: 0.62 seconds
# Batch 187/254: 0.65 seconds
# Batch 188/254: 0.62 seconds
# Batch 189/254: 0.66 seconds
# Batch 190/254: 0.62 seconds
# Batch 191/254: 0.69 seconds
# Batch 192/254: 0.62 seconds
# Batch 193/254: 0.63 seconds
# Batch 194/254: 0.62 seconds
# Batch 195/254: 0.64 seconds
# Batch 196/254: 0.65 seconds
# Batch 197/254: 0.62 seconds
# Batch 198/254: 0.62 seconds
# Batch 199/254: 0.94 seconds
# Batch 200/254: 0.73 seconds
# Batch 201/254: 0.64 seconds
# Batch 202/254: 0.69 seconds
# Batch 203/254: 0.71 seconds
# Batch 204/254: 0.65 seconds
# Batch 205/254: 0.67 seconds
# Batch 206/254: 0.68 seconds
# Batch 207/254: 0.74 seconds
# Batch 208/254: 0.73 seconds
# Batch 209/254: 0.73 seconds
# Batch 210/254: 0.73 seconds
# Batch 211/254: 0.73 seconds
# Batch 212/254: 0.75 seconds
# Batch 213/254: 0.72 seconds
# Batch 214/254: 1.06 seconds
# Batch 215/254: 0.74 seconds
# Batch 216/254: 0.74 seconds
# Batch 217/254: 0.73 seconds
# Batch 218/254: 0.75 seconds
# Batch 219/254: 0.76 seconds
# Batch 220/254: 0.73 seconds
# Batch 221/254: 0.79 seconds
# Batch 222/254: 0.73 seconds
# Batch 223/254: 0.73 seconds
# Batch 224/254: 0.73 seconds
# Batch 225/254: 0.73 seconds
# Batch 226/254: 0.78 seconds
# Batch 227/254: 0.79 seconds
# Batch 228/254: 1.01 seconds
# Batch 229/254: 0.73 seconds
# Batch 230/254: 0.73 seconds
# Batch 231/254: 0.78 seconds
# Batch 232/254: 0.73 seconds
# Batch 233/254: 0.75 seconds
# Batch 234/254: 0.85 seconds
# Batch 235/254: 0.72 seconds
# Batch 236/254: 0.73 seconds
# Batch 237/254: 0.73 seconds
# Batch 238/254: 0.75 seconds
# Batch 239/254: 0.74 seconds
# Batch 240/254: 0.72 seconds
# Batch 241/254: 0.94 seconds
# Batch 242/254: 0.81 seconds
# Batch 243/254: 0.73 seconds
# Batch 244/254: 0.72 seconds
# Batch 245/254: 0.68 seconds
# Batch 246/254: 0.73 seconds
# Batch 247/254: 0.63 seconds
# Batch 248/254: 0.81 seconds
# Batch 249/254: 0.72 seconds
# Batch 250/254: 0.73 seconds
# Batch 251/254: 0.73 seconds
# Batch 252/254: 0.65 seconds
# Batch 253/254: 0.71 seconds
# Batch 254/254: 0.45 seconds
# Classified 17.82 % of validation images correctly.
# Precision on validation set: [0.         0.         0.         0.         0.17823344 0.
#  0.         0.        ]
# Recall on validation set: [0. 0. 0. 0. 1. 0. 0. 0.]
# F1-score on validation set: [0.         0.         0.         0.         0.30254351 0.
#  0.         0.        ]
# /home/arttu/miniconda3/envs/leanheat/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC on validation set: {'AK': 0.5, 'BCC': 0.5, 'BKL': 0.5, 'DF': 0.5, 'MEL': 0.5, 'NV': 0.5, 'SCC': 0.5, 'VASC': 0.5}
# Confusion matrix on validation set:
#                  pred as AK  pred as BCC  pred as BKL  pred as DF  \
# true class AK             0            0            0           0
# true class BCC            0            0            0           0
# true class BKL            0            0            0           0
# true class DF             0            0            0           0
# true class MEL            0            0            0           0
# true class NV             0            0            0           0
# true class SCC            0            0            0           0
# true class VASC           0            0            0           0
#
#                  pred as MEL  pred as NV  pred as SCC  pred as VASC
# true class AK             43           0            0             0
# true class BCC           167           0            0             0
# true class BKL           131           0            0             0
# true class DF             12           0            0             0
# true class MEL           226           0            0             0
# true class NV            644           0            0             0
# true class SCC            32           0            0             0
# true class VASC           13           0            0             0
